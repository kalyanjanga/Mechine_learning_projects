# %% [markdown]
# # problem statement
# - predict the diabetes  with the given features

# %% [markdown]
# ##### In india there were 101 million people effected with diabetes
# ##### india ranked second place in diabetes all over the world ,then i decide to train model to predict the diabetes

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# reading file
df = pd.read_csv("/content/drive/MyDrive/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# checking columns
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# checking datatype of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 663 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               663 non-null    int64
#  1   Glucose                   663 non-null    int64
#  2   BloodPressure             663 non-null    int64
#  3   SkinThickness             663 non-null    int64
#  4   Insulin                   663 non-null    int64
#  5   BMI                       663 non-null    float64
#  6   DiabetesPedigreeFunction  663 non-null    float64
#  7   Age                       663 non-null    int64
#  8   Outcome                   663 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 51.8 KB

# %%
# dataframe shape
df.shape
# Out:
# (663, 9)

# %%
# cheking null values
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # observations :
# - Ther are no null values

# %%
# finding min,max and  median and  mean and std, count
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# cheking duplicate files
df. duplicated(keep="first").sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# # Exploratory data analysis
# ## univariate anaysis

# %%
#  function visualization
def univariate(df):
  for i in df.columns:
    print("*"*10,i,"*")
    sns.boxplot(x=i,data=df)
    plt.title(f"boxplot plot of {i}")
    plt.show()


    print("*"*10,i,"*"*10)

    df[i].plot(kind="hist")
    plt.title(f"histogram plot of {i}")
    plt.show()

    print("*"*10,i,"*"*10)

    df[i].plot(kind="kde")
    plt.title(f"density plot of {i}")
    plt.show()

    des_ = df[i].describe().T
    print(des_)

    skew_ =df[i].skew()
    print("skewness",skew_)

    kurt_ =df[i].kurt()
    print("kurtosis",kurt_)

# %%
# visual univariate analysis
univariate(df)
# Out:
# ********** Pregnancies *
# ********** Pregnancies **********
# ********** Pregnancies **********
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64
# skewness 0.9016739791518588
# kurtosis 0.15921977754746486
# ********** Glucose *
# ********** Glucose **********
# ********** Glucose **********
# count    768.000000
# mean     120.894531
# std       31.972618
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64
# skewness 0.17375350179188992
# kurtosis 0.6407798203735053
# ********** BloodPressure *
# ********** BloodPressure **********
# ********** BloodPressure **********
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64
# skewness -1.8436079833551302
# kurtosis 5.180156560082496
# ********** SkinThickness *
# ********** SkinThickness **********
# ********** SkinThickness **********
# count    768.000000
# mean      20.536458
# std       15.952218
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64
# skewness 0.10937249648187608
# kurtosis -0.520071866153013
# ********** Insulin *
# ********** Insulin **********
# ********** Insulin **********
# count    768.000000
# mean      79.799479
# std      115.244002
# min        0.000000
# 25%        0.000000
# 50%       30.500000
# 75%      127.250000
# max      846.000000
# Name: Insulin, dtype: float64
# skewness 2.272250858431574
# kurtosis 7.2142595543487715
# ********** BMI *
# ********** BMI **********
# ********** BMI **********
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64
# skewness -0.42898158845356543
# kurtosis 3.290442900816981
# ********** DiabetesPedigreeFunction *
# ********** DiabetesPedigreeFunction **********
# ********** DiabetesPedigreeFunction **********
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64
# skewness 1.919911066307204
# kurtosis 5.5949535279830584
# ********** Age *
# ********** Age **********
# ********** Age **********
# count    768.000000
# mean      33.240885
# std       11.760232
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64
# skewness 1.1295967011444805
# kurtosis 0.6431588885398942
# ********** Outcome *
# ********** Outcome **********
# ********** Outcome **********
# count    768.000000
# mean       0.348958
# std        0.476951
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Outcome, dtype: float64
# skewness 0.635016643444986
# kurtosis -1.600929755156027

# %%
# statistical way to  represent the outliers
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
# kurtosis shows the tailness of the distribution
# numbers indicate the outlier
df.kurt()
# Out:
# Pregnancies                 0.159220
# Glucose                     0.640780
# BloodPressure               5.180157
# SkinThickness              -0.520072
# Insulin                     7.214260
# BMI                         3.290443
# DiabetesPedigreeFunction    5.594954
# Age                         0.643159
# Outcome                    -1.600930
# dtype: float64

# %%
# outliers detection # only  stores the first column
def outlier_detection(df,col):
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)

  iqr = q3-q1

  # lower boundary
  l = q1-(1.5*iqr)
  # upper boundary
  u = q3+(1.5*iqr)
  outliers =df[(df[col]<l)| (df[col]>u)]
  return outliers

# %%
# outliers detection
def outlier_detection_all(df):
  for i in df.columns:
    q1 = df[i].quantile(0.25)
    q3 = df[i].quantile(0.75)

    iqr = q3-q1

    # lower boundary
    l = q1-(1.5*iqr)
    # upper boundary
    u = q3+(1.5*iqr)
    outliers =df[(df[i]<l)| (df[i]>u)]
    print( outliers)
    print("*"*50)
    print(f"count of outlies {i}",len(outliers))
    print("*"*50)

# %%
out =outlier_detection_all(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 88            15      136             70             32      110  37.1
# 159           17      163             72             41      114  40.9
# 298           14      100             78             25      184  36.6
# 455           14      175             62             30        0  33.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 88                      0.153   43        1
# 159                     0.817   47        1
# 298                     0.412   46        1
# 455                     0.212   38        1
# **************************************************
# count of outlies Pregnancies 4
# **************************************************
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 123            5      132             80              0        0  26.8
# 363            4      146             78              0        0  38.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
# 489            8      194             80              0        0  26.1
# 537            0       57             60              0        0  21.7
# 666            4      145             82             18        0  32.5
# 674            8       91             82              0        0  35.6
# 684            5      136             82              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 123                     0.186   69        0
# 363                     0.520   67        1
# 453                     0.832   72        0
# 459                     0.460   81        0
# 489                     0.551   67        0
# 537                     0.735   67        0
# 666                     0.235   70        1
# 674                     0.587   68        0
# 684                     0.640   69        0
# **************************************************
# count of outlies Age 9
# **************************************************
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
# **************************************************
# count of outlies Outcome 0
# **************************************************

# %%
# outliers detection in columns
outlier_detection(df,"Pregnancies")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 88            15      136             70             32      110  37.1
# 159           17      163             72             41      114  40.9
# 298           14      100             78             25      184  36.6
# 455           14      175             62             30        0  33.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 88                      0.153   43        1
# 159                     0.817   47        1
# 298                     0.412   46        1
# 455                     0.212   38        1

# %%
outlier_detection(df,"Glucose")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 182            1        0             74             20       23  27.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
outlier_detection(df,"BloodPressure")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7             10      115              0              0        0  35.3
# 15             7      100              0              0        0  30.0
# 18             1      103             30             38       83  43.3
# 43             9      171            110             24      240  45.4
# 49             7      105              0              0        0   0.0
# 60             2       84              0              0        0   0.0
# 78             0      131              0              0        0  43.2
# 81             2       74              0              0        0   0.0
# 84             5      137            108              0        0  48.8
# 106            1       96            122              0        0  22.4
# 125            1       88             30             42       99  55.0
# 172            2       87              0             23        0  28.9
# 177            0      129            110             46      130  67.1
# 193           11      135              0              0        0  52.3
# 222            7      119              0              0        0  25.2
# 261            3      141              0              0        0  30.0
# 266            0      138              0              0        0  36.3
# 269            2      146              0              0        0  27.5
# 300            0      167              0              0        0  32.3
# 332            1      180              0              0        0  43.3
# 336            0      117              0              0        0  33.8
# 347            3      116              0              0        0  23.5
# 357           13      129              0             30        0  39.9
# 362            5      103            108             37        0  39.2
# 426            0       94              0              0        0   0.0
# 430            2       99              0              0        0  22.2
# 435            0      141              0              0        0  42.4
# 453            2      119              0              0        0  19.6
# 468            8      120              0              0        0  30.0
# 484            0      145              0              0        0  44.2
# 494            3       80              0              0        0   0.0
# 522            6      114              0              0        0   0.0
# 533            6       91              0              0        0  29.8
# 535            4      132              0              0        0  32.9
# 549            4      189            110             31        0  28.5
# 383            1       90             62             18       59  25.1
# 395            2      127             58             24      275  27.7
# 445            0      180             78             63       14  59.4
# 534            1       77             56             30       56  33.3
# 593            2       82             52             22      115  28.5
# 606            1      181             78             42      293  40.0
# 618            9      112             82             24        0  28.2
# 621            2       92             76             20        0  24.2
# 622            6      183             94              0        0  40.8
# 659            3       80             82             31       70  34.2
# 661            1      199             76             43        0  42.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 4                       2.288   33        1
# 12                      1.441   57        0
# 39                      1.390   56        1
# 45                      1.893   25        1
# 58                      1.781   44        0
# 100                     1.222   33        1
# 147                     1.400   34        0
# 187                     1.321   33        1
# 218                     1.224   32        1
# 228                     2.329   31        0
# 243                     1.318   33        1
# 245                     1.213   49        1
# 259                     1.353   51        1
# 292                     1.224   31        1
# 308                     1.391   25        1
# 330                     1.476   46        0
# 370                     2.137   25        1
# 371                     1.731   21        0
# 383                     1.268   25        0
# 395                     1.600   25        0
# 445                     2.420   25        1
# 534                     1.251   24        0
# 593                     1.699   25        0
# 606                     1.258   22        1
# 618                     1.282   50        1
# 621                     1.698   28        0
# 622                     1.461   45        0
# 659                     1.292   27        1
# 661                     1.394   22        1

# %%
len(outlier_detection(df,"DiabetesPedigreeFunction"))
# Out:
# 29

# %%
outlier_detection(df,"Age")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 123            5      132             80              0        0  26.8
# 363            4      146             78              0        0  38.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
# 489            8      194             80              0        0  26.1
# 537            0       57             60              0        0  21.7
# 666            4      145             82             18        0  32.5
# 674            8       91             82              0        0  35.6
# 684            5      136             82              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 123                     0.186   69        0
# 363                     0.520   67        1
# 453                     0.832   72        0
# 459                     0.460   81        0
# 489                     0.551   67        0
# 537                     0.735   67        0
# 666                     0.235   70        1
# 674                     0.587   68        0
# 684                     0.640   69        0

# %%
len(outlier_detection(df,"Age"))
# Out:
# 9

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # observation
# - There are 145 outliers in the dataframe
# - In BMI  19
# - In Age 9
# - In DiabetesPedigreeFunction 29
# - In Insulin 34
# - In Glouose 5
# - In pregnanies 4
# - In Bp 45

# %%
# outliers removing
def outlier_deletion(df,col):
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)

  iqr = q3-q1

  # lower boundary
  l = q1-(1.5*iqr)
  # upper boundary
  u = q3+(1.5*iqr)
  df=df[(df[col]>l)&(df[col]<u)]
  return df

# %%
df=outlier_deletion(df,"BloodPressure") # removing outliers in bp
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [723 rows x 9 columns]

# %%
df=outlier_deletion(df,"DiabetesPedigreeFunction")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 5                       0.201   30        0
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [694 rows x 9 columns]

# %%
df=outlier_deletion(df,"Insulin")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 5                       0.201   30        0
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [663 rows x 9 columns]

# %% [markdown]
# # bi variate analysis betwen to num features

# %%
def min_max(df):
  for i in df.columns:
    print(i,"min")
    print(df[i].min())

    print(i,"max")
    print(df[i].max())

# %%
# range of all features
min_max(df)
# Out:
# Pregnancies min
# 0
# Pregnancies max
# 17
# Glucose min
# 0
# Glucose max
# 199
# BloodPressure min
# 0
# BloodPressure max
# 122
# SkinThickness min
# 0
# SkinThickness max
# 99
# Insulin min
# 0
# Insulin max
# 846
# BMI min
# 0.0
# BMI max
# 67.1
# DiabetesPedigreeFunction min
# 0.078
# DiabetesPedigreeFunction max
# 2.42
# Age min
# 21
# Age max
# 81
# Outcome min
# 0
# Outcome max
# 1

# %%
# bi variate analysis
clo2 = df["Outcome"]
for i in df.columns:
  def scatter(df,col1,col2):
    print("*"*15,i,"*"*15)
    sns.scatterplot(x=df[col1],y=df[col2])
    plt.title(f"scatter plot of {col1,col2}")
    plt.show()

# %%
scatter(df,"Pregnancies","Outcome")
# Out:
# *************** Outcome ***************

# %%
scatter(df,"Glucose","Outcome")
# Out:
# *************** Outcome ***************

# %%
scatter(df,"BloodPressure","Outcome")
# Out:
# *************** Outcome ***************

# %%
scatter(df,"SkinThickness","Outcome")
# Out:
# *************** Outcome ***************

# %%
scatter(df,"Insulin","Outcome")
# Out:
# *************** Outcome ***************

# %%
scatter(df,"BMI","Outcome")
# Out:
# *************** Outcome ***************

# %%
scatter(df,"DiabetesPedigreeFunction","Outcome")
# Out:
# *************** Outcome ***************

# %%
scatter(df,"Age","Outcome")
# Out:
# *************** Outcome ***************

# %%
df["Outcome"].value_counts().plot(kind="barh")
plt.title("the predicted values indicates")
# Out:
# Text(0.5, 1.0, 'the predicted values indicates')

# %%
sns.countplot(x=df["Outcome"])
plt.title("target features counts")
plt.show()

# %%
df["Outcome"].value_counts(normalize=True) # for in percentage
# Out:
# 0    0.678733
# 1    0.321267
# Name: Outcome, dtype: float64

# %%
df["Outcome"].value_counts()
# Out:
# 0    450
# 1    213
# Name: Outcome, dtype: int64

# %% [markdown]
# # observations:
#  - In the 60%  are non diabetic people 500
#  - There are 268 are diabetic holders are presented in data

# %%
sns.scatterplot(x="Pregnancies",y="BloodPressure",hue="Outcome",data=df)
# Out:
# <Axes: xlabel='Pregnancies', ylabel='BloodPressure'>

# %%
# non visual visual bi variate analysis
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.157095       0.207969      -0.082637
# Glucose                      0.157095  1.000000       0.234543       0.008631
# BloodPressure                0.207969  0.234543       1.000000       0.026144
# SkinThickness               -0.082637  0.008631       0.026144       1.000000
# Insulin                     -0.095501  0.246925      -0.029779       0.473251
# BMI                          0.043797  0.170999       0.281854       0.383170
# DiabetesPedigreeFunction     0.007160  0.071060       0.030975       0.155962
# Age                          0.546557  0.280968       0.340021      -0.140194
# Outcome                      0.245918  0.458841       0.187588       0.053446
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.095501  0.043797                  0.007160
# Glucose                   0.246925  0.170999                  0.071060
# BloodPressure            -0.029779  0.281854                  0.030975
# SkinThickness             0.473251  0.383170                  0.155962
# Insulin                   1.000000  0.203841                  0.219619
# BMI                       0.203841  1.000000                  0.143475
# DiabetesPedigreeFunction  0.219619  0.143475                  1.000000
# Age                      -0.105652  0.015100                  0.037044
# Outcome                   0.097629  0.270773                  0.172340
#
#                                Age   Outcome
# Pregnancies               0.546557  0.245918
# Glucose                   0.280968  0.458841
# BloodPressure             0.340021  0.187588
# SkinThickness            -0.140194  0.053446
# Insulin                  -0.105652  0.097629
# BMI                       0.015100  0.270773
# DiabetesPedigreeFunction  0.037044  0.172340
# Age                       1.000000  0.254210
# Outcome                   0.254210  1.000000

# %% [markdown]
# # observations :
# - The age and Pregnancies  positive corelation with 0.54
# - THe Glucose and  outcomes have positive corelation each other 0.46

# %% [markdown]
# # building model to predict the diabetes

# %%
# identify  input and output features
X = df.drop("Outcome",axis=1)
y = df["Outcome"]

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 5                     0.201   30

# %%
X.shape
# Out:
# (663, 8)

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 5    0
# Name: Outcome, dtype: int64

# %%
y.value_counts()
# Out:
# 0    450
# 1    213
# Name: Outcome, dtype: int64

# %%
# split the data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size= 0.20,random_state =0)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (530, 8) (530,)
# (133, 8) (133,)

# %%
# data preprocessing of train data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_rescaled = pd.DataFrame(scaler.fit_transform(X_train),
                                columns=X_train.columns,
                                index=X_train.index)
X_train_rescaled.head()
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 675     0.612036  2.466098      -0.176823      -1.316861 -0.817574 -0.169717
# 333     2.379770 -0.394209       0.690920      -1.316861 -0.817574 -1.214319
# 239    -1.155698 -0.458486       0.343823      -1.316861 -0.817574 -1.958419
# 594     0.612036  0.152141      -0.003275       1.530825  2.135558  0.216642
# 627    -1.155698  0.441386       0.517371      -1.316861 -0.817574  0.044927
#
#      DiabetesPedigreeFunction       Age
# 675                 -0.412801 -0.188684
# 333                 -1.168965  0.933000
# 239                  0.592777 -0.533817
# 594                  1.190582  0.070166
# 627                 -0.155468 -1.051517

# %% [markdown]
# # logisticregression algorithm

# %%
# building model
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()
reg.fit(X_train_rescaled,y_train)
# Out:
# LogisticRegression()

# %%
# predictions on train data
y_train_pred = reg.predict(X_train_rescaled)

# %%
# evalution of the train data
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(y_train,y_train_pred)
# Out:
# 0.7849056603773585

# %%
# preprocesing of test data
X_test_rescaled = pd.DataFrame(scaler.transform(X_test),
                               columns=X_test.columns,
                               index=X_test.index)
X_test_rescaled.head()
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 492     0.022792 -0.619177      -0.350372       1.087852 -0.817574  0.102165
# 359    -0.861075  2.498237       0.343823       0.961288  2.379512  0.631621
# 21      1.201281 -0.619177       1.038017      -1.316861 -0.817574  0.474215
# 743     1.495903  0.698492       1.905759      -1.316861 -0.817574  0.087856
# 92      0.906658 -1.197667       0.517371       1.214416 -0.201268  2.091201
#
#      DiabetesPedigreeFunction       Age
# 492                 -1.137293 -0.016117
# 359                  1.752756 -0.361250
# 21                  -0.175263  1.450700
# 743                  1.194541  1.019283
# 92                  -0.678052  0.760433

# %%
# prediction
y_test_predi_l =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_score",metrics.accuracy_score(y_test,y_test_predi_l))
print("accauracy_score",metrics.classification_report(y_test,y_test_predi_l))
# Out:
# accauracy_score 0.8345864661654135
# accauracy_score               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89        93
#            1       0.82      0.57      0.68        40
#
#     accuracy                           0.83       133
#    macro avg       0.83      0.76      0.78       133
# weighted avg       0.83      0.83      0.83       133

# %% [markdown]
# # KNN algorithm

# %%
# building model
from sklearn.neighbors import KNeighborsClassifier
reg = KNeighborsClassifier()
reg.fit(X_train_rescaled,y_train)

# prediction on train data
y_train_pred_knn=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data ",accuracy_score(y_train,y_train_pred_knn))
# prediction on test data
y_test_predi_k =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_score of test data",metrics.accuracy_score(y_test,y_test_predi_k))
print("accauracy_score of test data",metrics.classification_report(y_test,y_test_predi_k))
# Out:
# train data  0.8037735849056604
# accauracy_score of test data 0.7969924812030075
# accauracy_score of test data               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86        93
#            1       0.72      0.53      0.61        40
#
#     accuracy                           0.80       133
#    macro avg       0.77      0.72      0.74       133
# weighted avg       0.79      0.80      0.79       133

# %% [markdown]
# # decision tree algorithm

# %%
# building model
from sklearn.tree import DecisionTreeClassifier
reg = DecisionTreeClassifier(max_depth=3) # max depth is hyperparameter
reg.fit(X_train_rescaled,y_train)

# prediction on train data
y_train_pred_dt=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data of dt  ",accuracy_score(y_train,y_train_pred_dt))

# prediction
y_test_predi_d =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_score of dt",metrics.accuracy_score(y_test,y_test_predi_d))
print("accauracy_score of dt",metrics.classification_report(y_test,y_test_predi_d))
# Out:
# train data of dt   0.7754716981132076
# accauracy_score of dt 0.7744360902255639
# accauracy_score of dt               precision    recall  f1-score   support
#
#            0       0.78      0.95      0.85        93
#            1       0.75      0.38      0.50        40
#
#     accuracy                           0.77       133
#    macro avg       0.76      0.66      0.68       133
# weighted avg       0.77      0.77      0.75       133

# %% [markdown]
# # support vector  algorithm

# %%
# building model
from sklearn.svm import SVC
reg = SVC()
reg.fit(X_train_rescaled,y_train)


# prediction on train data
y_train_pred_svc=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data ",accuracy_score(y_train,y_train_pred_svc))

# prediction
y_test_predi_s =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_scaore of svc",metrics.accuracy_score(y_test,y_test_predi_s))
print("accauracy_scaore svc ",metrics.classification_report(y_test,y_test_predi_s))
# Out:
# train data  0.8358490566037736
# accauracy_scaore of svc 0.849624060150376
# accauracy_scaore svc                precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90        93
#            1       0.86      0.60      0.71        40
#
#     accuracy                           0.85       133
#    macro avg       0.85      0.78      0.80       133
# weighted avg       0.85      0.85      0.84       133

# %% [markdown]
# # naive bayes algorithm

# %%
# building model
from sklearn.naive_bayes import GaussianNB
reg = GaussianNB()
reg.fit(X_train_rescaled,y_train)

# prediction on train data
y_train_pred_nb=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data ",accuracy_score(y_train,y_train_pred_nb))

# prediction
y_test_predi_nb =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_score of nb",metrics.accuracy_score(y_test,y_test_predi_nb))
print("accauracy_score of nb",metrics.classification_report(y_test,y_test_predi_nb))
# Out:
# train data  0.7528301886792453
# accauracy_score of nb 0.7819548872180451
# accauracy_score of nb               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84        93
#            1       0.63      0.65      0.64        40
#
#     accuracy                           0.78       133
#    macro avg       0.74      0.74      0.74       133
# weighted avg       0.78      0.78      0.78       133

# %% [markdown]
# # ensemble algorithms
# ## random forest algorithm

# %%
# building model
from sklearn.ensemble import RandomForestClassifier
reg = RandomForestClassifier()
reg.fit(X_train_rescaled,y_train)

# prediction on train data
y_train_pred_rf=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data ",accuracy_score(y_train,y_train_pred_rf))

# prediction
y_test_predi_r =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_score of rf",metrics.accuracy_score(y_test,y_test_predi_r))
print("accauracy_score of rf",metrics.classification_report(y_test,y_test_predi_r))
# Out:
# train data  1.0
# accauracy_score of rf 0.8120300751879699
# accauracy_score of rf               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        93
#            1       0.73      0.60      0.66        40
#
#     accuracy                           0.81       133
#    macro avg       0.78      0.75      0.76       133
# weighted avg       0.81      0.81      0.81       133

# %% [markdown]
# # adaboost algorithm

# %%
# building model
from sklearn.ensemble import AdaBoostClassifier
reg = AdaBoostClassifier()
reg.fit(X_train_rescaled,y_train)

# prediction on train data
y_train_pred_adb=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data ",accuracy_score(y_train,y_train_pred_adb))

# prediction
y_test_predi_a =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_score of ada boost",metrics.accuracy_score(y_test,y_test_predi_a))
print("accauracy_score ada boost",metrics.classification_report(y_test,y_test_predi_a))
# Out:
# train data  0.8132075471698114
# accauracy_score of ada boost 0.7969924812030075
# accauracy_score ada boost               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86        93
#            1       0.71      0.55      0.62        40
#
#     accuracy                           0.80       133
#    macro avg       0.77      0.73      0.74       133
# weighted avg       0.79      0.80      0.79       133

# %% [markdown]
# # gbdt algorithm

# %%
# building model
from sklearn.ensemble import GradientBoostingClassifier
reg = GradientBoostingClassifier()
reg.fit(X_train_rescaled,y_train)

# prediction on train data
y_train_pred_gbdt=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data ",accuracy_score(y_train,y_train_pred_gbdt))

# prediction
y_test_predi_g =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_score gbdt",metrics.accuracy_score(y_test,y_test_predi_g))
print("accauracy_score gbdt ",metrics.classification_report(y_test,y_test_predi_g))
# Out:
# train data  0.9415094339622642
# accauracy_score gbdt 0.8571428571428571
# accauracy_score gbdt                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        93
#            1       0.80      0.70      0.75        40
#
#     accuracy                           0.86       133
#    macro avg       0.84      0.81      0.82       133
# weighted avg       0.85      0.86      0.85       133

# %% [markdown]
# # Xgboost algorithm

# %%
# building model
from sklearn.ensemble import ExtraTreesClassifier
reg = ExtraTreesClassifier()
reg.fit(X_train_rescaled,y_train)

# prediction on yttrain data
y_train_pred_xg=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data ",accuracy_score(y_train,y_train_pred_xg))

# prediction on yttrain data
y_train_pred_knn=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data ",accuracy_score(y_train,y_train_pred_knn))
# prediction
y_test_predi_g =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_score xg",metrics.accuracy_score(y_test,y_test_predi_g))
print("accauracy_score xg",metrics.classification_report(y_test,y_test_predi_g))
# Out:
# train data  1.0
# train data  1.0
# accauracy_score xg 0.8120300751879699
# accauracy_score xg               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87        93
#            1       0.74      0.57      0.65        40
#
#     accuracy                           0.81       133
#    macro avg       0.79      0.74      0.76       133
# weighted avg       0.81      0.81      0.80       133

# %% [markdown]
# # feature importance

# %%
# building model
from sklearn.tree import DecisionTreeClassifier
reg = DecisionTreeClassifier(max_depth=3) # max depth is hyperparameter
reg.fit(X_train_rescaled,y_train)

# prediction on train data
y_train_pred_dt=reg.predict(X_train_rescaled)
# evalution of the train data
print("train data of dt  ",accuracy_score(y_train,y_train_pred_dt))

# prediction
y_test_predi_d =reg.predict(X_test_rescaled)
from sklearn import metrics
print("accauracy_score of dt",metrics.accuracy_score(y_test,y_test_predi_d))
print("accauracy_score of dt",metrics.classification_report(y_test,y_test_predi_d))
# Out:
# train data of dt   0.7754716981132076
# accauracy_score of dt 0.7744360902255639
# accauracy_score of dt               precision    recall  f1-score   support
#
#            0       0.78      0.95      0.85        93
#            1       0.75      0.38      0.50        40
#
#     accuracy                           0.77       133
#    macro avg       0.76      0.66      0.68       133
# weighted avg       0.77      0.77      0.75       133

# %%
reg.feature_importances_
# Out:
# array([0.0205215 , 0.57807006, 0.        , 0.        , 0.        ,
#        0.11764441, 0.07218331, 0.21158072])

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,8))
s =plot_tree(reg,feature_names=X_train_rescaled.columns,
             class_names =["0","1"],
             filled = True,
             rounded = True,
             fontsize = 15)

# %% [markdown]
# # feature selection with decision tree

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = reg.feature_importances_,y=X_train_rescaled.columns)
# Out:
# <Axes: >

# %% [markdown]
# # observations :
# - The above  plot show the most important feature of given the data
# - The Glucose most important feature a to compare with others feature
# - Age and Bmi are also important features to predict the diabetes
